# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import spektral
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import kneighbors_graph

# %%
def change_datatype(df):
    int8_vals = np.iinfo(np.int8)
    int16_vals = np.iinfo(np.int16)
    int32_vals = np.iinfo(np.int32)

    float16_vals = np.finfo(np.float16)
    float32_vals = np.finfo(np.float32)
    
    for col in df.columns:
        max_val = df[col].max()
        min_val = df[col].min()

        # print(f"{col}: max {max_val} -- min {min_val}")
        
        if df[col].dtype == np.int64:
            if max_val <= int8_vals.max and min_val >= int8_vals.min:
                df[col] = df[col].astype(np.int8)
            elif max_val <= int16_vals.max and min_val >= int16_vals.min:
                df[col] = df[col].astype(np.int16)
            elif max_val <= int32_vals.max and min_val >= int32_vals.min:
                df[col] = df[col].astype(np.int32)

        elif df[col].dtype == np.float64:
            if max_val <= float16_vals.max and min_val >= float16_vals.min:
                df[col] = df[col].astype(np.float16)
            elif max_val <= float32_vals.max and min_val >= float32_vals.min:
                df[col] = df[col].astype(np.float32)
    return df

# %%
df = change_datatype(pd.read_csv('./raw/very_small_for_checking.csv'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723 entries, 0 to 722
# Data columns (total 69 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   destination_port             723 non-null    int32
#  1   flow_duration                723 non-null    int32
#  2   total_fwd_packets            723 non-null    int16
#  3   total_backward_packets       723 non-null    int16
#  4   total_length_of_fwd_packets  723 non-null    int32
#  5   total_length_of_bwd_packets  723 non-null    int32
#  6   fwd_packet_length_max        723 non-null    int16
#  7   fwd_packet_length_min        723 non-null    int16
#  8   fwd_packet_length_mean       723 non-null    float16
#  9   fwd_packet_length_std        723 non-null    float16
#  10  bwd_packet_length_max        723 non-null    int16
#  11  bwd_packet_length_min        723 non-null    int16
#  12  bwd_packet_length_mean       723 non-null    float16
#  13  bwd_packet_length_std        723 non-null    float16
#  14  flow_bytes_s                 723 non-null    float32
#  15  flow_packets_s               723 non-null    float32
#  16  flow_iat_mean                723 non-null    float32
#  17  flow_iat_std                 723 non-null    float32
#  18  flow_iat_max                 723 non-null    int32
#  19  flow_iat_min                 723 non-null    int32
#  20  fwd_iat_total                723 non-null    int32
#  21  fwd_iat_mean                 723 non-null    float32
#  22  fwd_iat_std                  723 non-null    float32
#  23  fwd_iat_max                  723 non-null    int32
#  24  fwd_iat_min                  723 non-null    int32
#  25  bwd_iat_total                723 non-null    int32
#  26  bwd_iat_mean                 723 non-null    float32
#  27  bwd_iat_std                  723 non-null    float32
#  28  bwd_iat_max                  723 non-null    int32
#  29  bwd_iat_min                  723 non-null    int32
#  30  fwd_psh_flags                723 non-null    int8
#  31  fwd_urg_flags                723 non-null    int8
#  32  bwd_header_length            723 non-null    int16
#  33  fwd_packets_s                723 non-null    float32
#  34  bwd_packets_s                723 non-null    float32
#  35  min_packet_length            723 non-null    int16
#  36  max_packet_length            723 non-null    int16
#  37  packet_length_mean           723 non-null    float16
#  38  packet_length_std            723 non-null    float16
#  39  packet_length_variance       723 non-null    float32
#  40  fin_flag_count               723 non-null    int8
#  41  syn_flag_count               723 non-null    int8
#  42  rst_flag_count               723 non-null    int8
#  43  psh_flag_count               723 non-null    int8
#  44  ack_flag_count               723 non-null    int8
#  45  urg_flag_count               723 non-null    int8
#  46  cwe_flag_count               723 non-null    int8
#  47  ece_flag_count               723 non-null    int8
#  48  down_up_ratio                723 non-null    int8
#  49  average_packet_size          723 non-null    float16
#  50  avg_fwd_segment_size         723 non-null    float16
#  51  avg_bwd_segment_size         723 non-null    float16
#  52  subflow_fwd_packets          723 non-null    int16
#  53  subflow_fwd_bytes            723 non-null    int32
#  54  subflow_bwd_packets          723 non-null    int16
#  55  subflow_bwd_bytes            723 non-null    int32
#  56  init_win_bytes_forward       723 non-null    int32
#  57  init_win_bytes_backward      723 non-null    int32
#  58  act_data_pkt_fwd             723 non-null    int8
#  59  min_seg_size_forward         723 non-null    int8
#  60  active_mean                  723 non-null    float32
#  61  active_std                   723 non-null    float32
#  62  active_max                   723 non-null    int32
#  63  active_min                   723 non-null    int32
#  64  idle_mean                    723 non-null    float32
#  65  idle_std                     723 non-null    float32
#  66  idle_max                     723 non-null    int32
#  67  idle_min                     723 non-null    int32
#  68  label                        723 non-null    int8
# dtypes: float16(9), float32(15), int16(11), int32(20), int8(14)
# memory usage: 137.1 KB

# %%
class DQNFeatureSelectorAgent:
    def __init__(self, gcn, dqn):
        self.gcn = gcn
        self.dqn = dqn

        self.selected_features = None
        self.accuracy = 0

    def train(self, data):
        # Initialize the reward function
        def reward_function(accuracy):
            return accuracy

        # Train the DQN agent
        self.dqn.compile(loss='mse', optimizer='adam')
        self.dqn.fit(data, reward_function, epochs=self.num_epochs)

    def select_features(self, features):
        # Get the GCN representation of the features
        gcn_representation = self.gcn.predict(features)

        # Predict the Q value for each action using the DQN model
        q_values = self.dqn.predict(gcn_representation)

        # Select the action with the highest Q value
        selected_action = np.argmax(q_values)

        # Get the selected features
        selected_features = features[:, selected_action]

        return selected_features

# %%
class GCNFeatureSelector:
    def __init__(self, features, labels, num_agents, num_epochs):
        self.features = features
        self.labels = labels
        self.num_agents = num_agents
        self.num_epochs = num_epochs

        # Create the GCN model
        self.gcn = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(features.shape[1],)),
            tf.keras.layers.GCN(128, activation='relu'),
            tf.keras.layers.GCN(64, activation='relu'),
        ])

        # Create the DQN model
        self.dqn = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(64,)),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(num_agents, activation='linear'),
        ])

        # Initialize the agents
        self.agents = []
        for i in range(num_agents):
            agent = DQNFeatureSelectorAgent(self.gcn, self.dqn)
            self.agents.append(agent)

    def train(self):
        # Split the data into N parts
        data_splits = np.split(self.features, self.num_agents, axis=0)

        # Train each agent on its respective data split
        for i in range(self.num_agents):
            self.agents[i].train(data_splits[i])

    def select_features(self):
        # Select the subset of features that resulted in the highest accuracy on the downstream task
        best_features = None
        best_accuracy = 0

        for agent in self.agents:
            features = agent.selected_features
            accuracy = agent.accuracy

            if accuracy > best_accuracy:
                best_features = features
                best_accuracy = accuracy

        return best_features

# %%
X = df.drop('label', axis = 1)
y = df['label']

# %%
gcn_feature_selector = GCNFeatureSelector(X, y, num_agents = 10, num_epochs=  100)
gcn_feature_selector.train()
best_features = gcn_feature_selector.select_features()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\dataset\_8_GCN.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> gcn_feature_selector = GCNFeatureSelector(X, y, num_agents = 10, num_epochs=  100)
#       <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> gcn_feature_selector.train()
#       <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> best_features = gcn_feature_selector.select_features()
#
# d:\dataset\_8_GCN.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> self.num_epochs = num_epochs
#       <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> # Create the GCN model
#       <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> self.gcn = tf.keras.models.Sequential([
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     tf.keras.layers.Input(shape=(features.shape[1],)),
# ---> <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     tf.keras.layers.GCN(128, activation='relu'),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a>     tf.keras.layers.GCN(64, activation='relu'),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a> ])
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a> # Create the DQN model
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> self.dqn = tf.keras.models.Sequential([
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a>     tf.keras.layers.Input(shape=(64,)),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a>     tf.keras.layers.Dense(128, activation='relu'),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a>     tf.keras.layers.Dense(64, activation='relu'),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a>     tf.keras.layers.Dense(num_agents, activation='linear'),
#      <a href='vscode-notebook-cell:/d%3A/dataset/_8_GCN.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> ])
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'GCN'

# %%
best_features
